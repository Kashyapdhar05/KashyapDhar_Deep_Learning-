# %% [markdown]
# <a href="https://colab.research.google.com/github/Kashyapdhar05/KashyapDhar_Deep_Learning-/blob/main/EXP_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# --- 1. Load and Preprocess Data ---
fashion_mnist = tf.keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Normalize pixel values to be between 0 and 1
# Using float32 ensures we don't hit the TypeError from earlier
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Add channel dimension (28, 28) -> (28, 28, 1)
X_train = X_train[..., tf.newaxis]
X_test = X_test[..., tf.newaxis]

# Label names for the 10 categories
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# --- 2. Build the CNN Architecture ---
model = models.Sequential([
    # First Convolutional block: Finds simple patterns
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),

    # Second Convolutional block: Finds more complex shapes
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Final Convolutional block
    layers.Conv2D(64, (3, 3), activation='relu'),

    # Flattening and Dense layers for the final decision
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),  # Prevents overfitting on similar clothes
    layers.Dense(10, activation='softmax')
])

# --- 3. Compile and Train ---
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

print("Starting training on Fashion MNIST...")
history = model.fit(X_train, y_train, epochs=10,
                    validation_split=0.2, batch_size=64)

# --- 4. Final Evaluation ---
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc:.4f}")
# Out:
# Starting training on Fashion MNIST...
# Epoch 1/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.7596 - loss: 0.6558 - val_accuracy: 0.8441 - val_loss: 0.4227
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8512 - loss: 0.4143 - val_accuracy: 0.8708 - val_loss: 0.3539
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8731 - loss: 0.3512 - val_accuracy: 0.8850 - val_loss: 0.3168
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8859 - loss: 0.3179 - val_accuracy: 0.8908 - val_loss: 0.3024
# Epoch 5/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8964 - loss: 0.2891 - val_accuracy: 0.8971 - val_loss: 0.2855
# Epoch 6/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9031 - loss: 0.2703 - val_accuracy: 0.8957 - val_loss: 0.2760
# Epoch 7/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9077 - loss: 0.2510 - val_accuracy: 0.9021 - val_loss: 0.2695
# Epoch 8/10
# ...
